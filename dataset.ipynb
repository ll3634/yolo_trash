# %%
# !git clone https://github.com/ll3634/finalproject.git

# %%
import os.path
import xml.dom.minidom

# path = 'finalproject/trainval/VOC2007/Annotations'
path = 'data/trainval/VOC2007/Annotations'
files = os.listdir(path)
s = []
for xmlFile in files:
  if not os.path.isdir(xmlFile):
    dom = xml.dom.minidom.parse(os.path.join(path, xmlFile))
    root = dom.documentElement

    pathNode = root.getElementsByTagName('name')

    j = len(pathNode)
    for i in range(j):
      if pathNode[i].firstChild.data == "一次性快餐盒":
        pathNode[i].firstChild.data = "Disposable Fast Food Box"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "书籍纸张":
        pathNode[i].firstChild.data = "Book Paper"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "充电宝":
        pathNode[i].firstChild.data = "Power Bank"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "剩饭剩菜":
        pathNode[i].firstChild.data = "Leftovers"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "包":
        pathNode[i].firstChild.data = "Package"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "垃圾桶":
        pathNode[i].firstChild.data = "Trash Can"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "塑料器皿":
        pathNode[i].firstChild.data = "Plastic Utensils"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "塑料玩具":
        pathNode[i].firstChild.data = "Plastic Toys"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "塑料衣架":
        pathNode[i].firstChild.data = "Plastic Hangers"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "大骨头":
        pathNode[i].firstChild.data = "Big Bones"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "干电池":
        pathNode[i].firstChild.data = "Dry Battery"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "快递纸袋":
        pathNode[i].firstChild.data = "Express Paper Bag"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "插头电线":
        pathNode[i].firstChild.data = "Plug Wire"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "旧衣服":
        pathNode[i].firstChild.data = "Old Clothes"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "易拉罐":
        pathNode[i].firstChild.data = "Can"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "枕头":
        pathNode[i].firstChild.data = "Pillow"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "果皮果肉":
        pathNode[i].firstChild.data = "Peel and Pulp"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "毛绒玩具":
        pathNode[i].firstChild.data = "Stuffed Toy"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "污损塑料":
        pathNode[i].firstChild.data = "Defiled Plastic"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "污损用纸":
        pathNode[i].firstChild.data = "Contaminated paper"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "洗护用品":
        pathNode[i].firstChild.data = "Toilet care products"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "烟蒂":
        pathNode[i].firstChild.data = "Cigarette butts"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "牙签":
        pathNode[i].firstChild.data = "Toothpicks"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "玻璃器皿":
        pathNode[i].firstChild.data = "Glassware"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "砧板":
        pathNode[i].firstChild.data = "Baffle"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "筷子":
        pathNode[i].firstChild.data = "Chopsticks"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "纸盒纸箱":
        pathNode[i].firstChild.data = "Carton box"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "花盆":
        pathNode[i].firstChild.data = "Flower pot"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "茶叶渣":
        pathNode[i].firstChild.data = "Tea residue"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "菜帮菜叶":
        pathNode[i].firstChild.data = "Veggies"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "蛋壳":
        pathNode[i].firstChild.data = "Egg Shell"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "调料瓶":
        pathNode[i].firstChild.data = "Sauce Bottle"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "软膏":
        pathNode[i].firstChild.data = "Ointment"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "过期药物":
        pathNode[i].firstChild.data = "Expired Medicine"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "酒瓶":
        pathNode[i].firstChild.data = "Wine Bottle"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "金属厨具":
        pathNode[i].firstChild.data = "Metal Kitchenware"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "金属器皿":
        pathNode[i].firstChild.data = "Metal Utensils"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "金属食品罐":
        pathNode[i].firstChild.data = "Metal Food Cans"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "锅":
        pathNode[i].firstChild.data = "Pots"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "陶瓷器皿":
        pathNode[i].firstChild.data = "Ceramic utensils"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "鞋":
        pathNode[i].firstChild.data = "Shoes"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "食用油桶":
        pathNode[i].firstChild.data = "Edible Oil Drums"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "饮料瓶":
        pathNode[i].firstChild.data = "Bottles"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)
      elif pathNode[i].firstChild.data == "鱼骨":
        pathNode[i].firstChild.data = "Fish Bones"
        i = i + 1
        with open(os.path.join(path, xmlFile), 'w',encoding='utf8') as fh:
          dom.writexml(fh)


print('done')
# Out:
# done

# %%
import os
import xml.dom.minidom

path = r'data/trainval/VOC2007/Annotations'
#sv_path = r'finalproject/trainval/VOC2007/Annotations1'
files = os.listdir(path)

for xmlFile in files:
    dom = xml.dom.minidom.parse(os.path.join(path, xmlFile))
    root = dom.documentElement
    item = root.getElementsByTagName('path')
    a, b = os.path.splitext(xmlFile)
    for i in item:
        i.firstChild.data = f'finalproject/trainval/VOC2007/JPEGImages/' + a + '.jpg'
    
    with open(os.path.join(path, xmlFile), 'w',encoding='utf-8') as fh:
          dom.writexml(fh)
print('done')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/xf/sg7ngz3n4q78m3g2_www4h9w0000gq/T/ipykernel_97625/2000659283.py in <module>
#       4 path = r'~/yolov7/trash_yolov7/data/trainval/VOC2007/Annotations'
#       5 #sv_path = r'finalproject/trainval/VOC2007/Annotations1'
# ----> 6 files = os.listdir(path)
#       7
#       8 for xmlFile in files:
#
# FileNotFoundError: [Errno 2] No such file or directory: '~/yolov7/trash_yolov7/data/trainval/VOC2007/Annotations'

# %%
import xml.etree.ElementTree as ET
import pickle
import os
from os import listdir, getcwd
from os.path import join
import random
from shutil import copyfile

# %%
classes=[ 'Disposable Fast Food Box',
          'Book Paper',
          'Power Bank',
          'Leftovers',
          'Package',
          'Trash Can',
          'Plastic Utensils',
          'Plastic Toys',
          'Plastic Hangers',
          'Big Bones',
          'Dry Battery',
          'Express Paper Bag',
          'Plug Wire',
          'Old Clothes',
          'Can',
          'Pillow',
          'Peel and Pulp',
          'Stuffed Toy',
          'Defiled Plastic',
          'Contaminated paper',
          'Toilet care products',
          'Cigarette butts',
          'Toothpicks',
          'Glassware',
          'Baffle',
          'Chopsticks',
          'Carton box',
          'Flower pot',
          'Tea residue',
          'Veggies',
          'Egg Shell',
          'Sauce Bottle',
          'Ointment',
          'Expired Medicine',
          'Wine Bottle',
          'Metal Kitchenware',
          'Metal Utensils',
          'Metal Food Cans',
          'Pots',
          'Ceramic utensils',
          'Shoes',
          'Edible Oil Drums',
          'Bottles',
          'Fish Bones' ]

# %%
TRAIN_RATIO = 80

def clear_hidden_files(path):
  dir_list = os.listdir(path)
  for i in dir_list:
    abspath = os.path.join(os.path.abspath(path), i)
    if os.path.isfile(abspath):
      if i.startswith("._"):
        os.remove(abspath)
    else:
      clear_hidden_files(abspath)

def convert(size, box):
  dw = 1./size[0]
  dh = 1./size[1]
  x = (box[0] + box[1])/2.0
  y = (box[2] + box[3])/2.0
  w = box[1] - box[0]
  h = box[3] - box[2]
  x = x*dw
  w = w*dw
  y = y*dh
  h = h*dh
  return (x,y,w,h)

def convert_annotation(image_id):
    in_file = open('data/trainval/VOC2007/Annotations/%s.xml' %image_id, encoding='utf-8')
    out_file = open('data/trainval/VOC2007/YOLOLabels/%s.txt' %image_id, 'w')
    tree=ET.parse(in_file)
    root = tree.getroot()
    size = root.find('size')
    w = int(size.find('width').text)
    h = int(size.find('height').text)

    for obj in root.iter('object'):
        difficult = obj.find('difficult').text
        cls = obj.find('name').text
        if cls not in classes or int(difficult) == 1:
            continue
        cls_id = classes.index(cls)
        xmlbox = obj.find('bndbox')
        b = (float(xmlbox.find('xmin').text), float(xmlbox.find('xmax').text), float(xmlbox.find('ymin').text), float(xmlbox.find('ymax').text))
        bb = convert((w,h), b)
        out_file.write(str(cls_id) + " " + " ".join([str(a) for a in bb]) + '\n')
    in_file.close()
    out_file.close()

# %%
wd = os.getcwd()
wd = os.getcwd()
data_base_dir = os.path.join(wd, "data/trainval/")
if not os.path.isdir(data_base_dir):
    os.mkdir(data_base_dir)
work_sapce_dir = os.path.join(data_base_dir, "VOC2007/")
if not os.path.isdir(work_sapce_dir):
    os.mkdir(work_sapce_dir)
annotation_dir = os.path.join(work_sapce_dir, "Annotations/")
if not os.path.isdir(annotation_dir):
        os.mkdir(annotation_dir)
clear_hidden_files(annotation_dir)
image_dir = os.path.join(work_sapce_dir, "JPEGImages/")
if not os.path.isdir(image_dir):
        os.mkdir(image_dir)
clear_hidden_files(image_dir)
yolo_labels_dir = os.path.join(work_sapce_dir, "YOLOLabels/")
if not os.path.isdir(yolo_labels_dir):
        os.mkdir(yolo_labels_dir)
clear_hidden_files(yolo_labels_dir)
yolov5_images_dir = os.path.join(data_base_dir, "images/")
if not os.path.isdir(yolov5_images_dir):
        os.mkdir(yolov5_images_dir)
clear_hidden_files(yolov5_images_dir)
yolov5_labels_dir = os.path.join(data_base_dir, "labels/")
if not os.path.isdir(yolov5_labels_dir):
        os.mkdir(yolov5_labels_dir)
clear_hidden_files(yolov5_labels_dir)
yolov5_images_train_dir = os.path.join(yolov5_images_dir, "train/")
if not os.path.isdir(yolov5_images_train_dir):
        os.mkdir(yolov5_images_train_dir)
clear_hidden_files(yolov5_images_train_dir)
yolov5_images_test_dir = os.path.join(yolov5_images_dir, "val/")
if not os.path.isdir(yolov5_images_test_dir):
        os.mkdir(yolov5_images_test_dir)
clear_hidden_files(yolov5_images_test_dir)
yolov5_labels_train_dir = os.path.join(yolov5_labels_dir, "train/")
if not os.path.isdir(yolov5_labels_train_dir):
        os.mkdir(yolov5_labels_train_dir)
clear_hidden_files(yolov5_labels_train_dir)
yolov5_labels_test_dir = os.path.join(yolov5_labels_dir, "val/")
if not os.path.isdir(yolov5_labels_test_dir):
        os.mkdir(yolov5_labels_test_dir)
clear_hidden_files(yolov5_labels_test_dir)

train_file = open(os.path.join(wd, "yolo_train.txt"), 'w')
test_file = open(os.path.join(wd, "yolo_val.txt"), 'w')
train_file.close()
test_file.close()
train_file = open(os.path.join(wd, "yolo_train.txt"), 'a')
test_file = open(os.path.join(wd, "yolo_val.txt"), 'a')
list_imgs = os.listdir(image_dir) # list image files
prob = random.randint(1, 100)
print("Probability: %d" % prob)
for i in range(0,len(list_imgs)):
    path = os.path.join(image_dir,list_imgs[i])
    if os.path.isfile(path):
        image_path = image_dir + list_imgs[i]
        voc_path = list_imgs[i]
        (nameWithoutExtention, extention) = os.path.splitext(os.path.basename(image_path))
        (voc_nameWithoutExtention, voc_extention) = os.path.splitext(os.path.basename(voc_path))
        annotation_name = nameWithoutExtention + '.xml'
        annotation_path = os.path.join(annotation_dir, annotation_name)
        label_name = nameWithoutExtention + '.txt'
        label_path = os.path.join(yolo_labels_dir, label_name)
    prob = random.randint(1, 100)
    print("Probability: %d" % prob)
    if(prob < TRAIN_RATIO): # train dataset
        if os.path.exists(annotation_path):
            train_file.write(image_path + '\n')
            convert_annotation(nameWithoutExtention) # convert label
            copyfile(image_path, yolov5_images_train_dir + voc_path)
            copyfile(label_path, yolov5_labels_train_dir + label_name)
    else: # test dataset
        if os.path.exists(annotation_path):
            test_file.write(image_path + '\n')
            convert_annotation(nameWithoutExtention) # convert label
            copyfile(image_path, yolov5_images_test_dir + voc_path)
            copyfile(label_path, yolov5_labels_test_dir + label_name)
train_file.close()
test_file.close()
# Out:
# Probability: 3
# Probability: 68
# Probability: 5
# Probability: 8
# Probability: 5
# Probability: 41
# Probability: 10
# Probability: 81
# Probability: 78
# Probability: 25
# Probability: 21
# Probability: 44
# Probability: 59
# Probability: 2
# Probability: 61
# Probability: 88
# Probability: 77
# Probability: 33
# Probability: 9
# Probability: 82
# Probability: 27
# Probability: 81
# Probability: 28
# Probability: 75
# Probability: 84
# Probability: 8
# Probability: 47
# Probability: 89
# Probability: 85
# Probability: 24
# Probability: 6
# Probability: 55
# Probability: 8
# Probability: 35
# Probability: 36
# Probability: 91
# Probability: 62
# Probability: 60
# Probability: 88
# Probability: 70
# Probability: 56
# Probability: 34
# Probability: 37
# Probability: 70
# Probability: 78
# Probability: 21
# Probability: 61
# Probability: 4
# Probability: 10
# Probability: 83
# Probability: 52
# Probability: 94
# Probability: 64
# Probability: 90
# Probability: 60
# Probability: 30
# Probability: 82
# Probability: 88
# Probability: 57
# Probability: 78
# Probability: 33
# Probability: 43
# Probability: 28
# Probability: 47
# Probability: 47
# Probability: 61
# Probability: 16
# Probability: 61
# Probability: 28
# Probability: 12
# Probability: 17
# Probability: 82
# Probability: 24
# Probability: 23
# Probability: 7
# Probability: 32
# Probability: 15
# Probability: 99
# Probability: 69
# Probability: 6
# Probability: 2
# Probability: 67
# Probability: 81
# Probability: 58
# Probability: 34
# Probability: 70
# Probability: 5
# Probability: 36
# Probability: 4
# Probability: 10
# Probability: 31
# Probability: 44
# Probability: 77
# Probability: 50
# Probability: 38
# Probability: 14
# Probability: 11
# Probability: 90
# Probability: 35
# Probability: 24
# Probability: 28
# Probability: 44
# Probability: 9
# Probability: 79
# Probability: 54
# Probability: 63
# Probability: 44
# Probability: 43
# Probability: 12
# Probability: 77
# Probability: 75
# Probability: 5
# Probability: 8
# Probability: 44
# Probability: 62
# Probability: 23
# Probability: 64
# Probability: 77
# Probability: 48
# Probability: 10
# Probability: 55
# Probability: 35
# Probability: 28
# Probability: 38
# Probability: 57
# Probability: 48
# Probability: 73
# Probability: 74
# Probability: 20
# Probability: 29
# Probability: 77
# Probability: 95
# Probability: 56
# Probability: 90
# Probability: 28
# Probability: 60
# Probability: 36
# Probability: 8
# Probability: 68
# Probability: 55
# Probability: 6
# Probability: 54
# Probability: 63
# Probability: 10
# Probability: 64
# Probability: 50
# Probability: 6
# Probability: 64
# Probability: 41
# Probability: 78
# Probability: 73
# Probability: 69
# Probability: 86
# Probability: 15
# Probability: 11
# Probability: 35
# Probability: 89
# Probability: 50
# Probability: 55
# Probability: 80
# Probability: 65
# Probability: 76
# Probability: 22
# Probability: 21
# Probability: 11
# Probability: 36
# Probability: 87
# Probability: 63
# Probability: 57
# Probability: 53
# Probability: 55
# Probability: 50
# Probability: 40
# Probability: 65
# Probability: 28
# Probability: 66
# Probability: 92
# Probability: 89
# Probability: 86
# Probability: 48
# Probability: 6
# Probability: 57
# Probability: 20
# Probability: 82
# Probability: 45
# Probability: 63
# Probability: 10
# Probability: 54
# Probability: 23
# Probability: 48
# Probability: 3
# Probability: 90
# Probability: 99
# Probability: 56
# Probability: 8
# Probability: 100
# Probability: 82
# Probability: 59
# Probability: 15
# Probability: 91
# Probability: 23
# Probability: 4
# Probability: 58
# Probability: 56
# Probability: 83
# Probability: 48
# Probability: 9
# Probability: 17
# Probability: 7
# Probability: 65
# Probability: 2
# Probability: 94
# Probability: 67
# Probability: 59
# Probability: 41
# Probability: 34
# Probability: 89
# Probability: 94
# Probability: 33
# Probability: 33
# Probability: 55
# Probability: 1
# Probability: 23
# Probability: 11
# Probability: 6
# Probability: 88
# Probability: 100
# Probability: 32
# Probability: 72
# Probability: 10
# Probability: 68
# Probability: 50
# Probability: 28
# Probability: 25
# Probability: 20
# Probability: 39
# Probability: 45
# Probability: 26
# Probability: 28
# Probability: 33
# Probability: 70
# Probability: 72
# Probability: 30
# Probability: 63
# Probability: 31
# Probability: 11
# Probability: 30
# Probability: 90
# Probability: 91
# Probability: 34
# Probability: 32
# Probability: 94
# Probability: 44
# Probability: 38
# Probability: 31
# Probability: 72
# Probability: 52
# Probability: 74
# Probability: 54
# Probability: 100
# Probability: 97
# Probability: 84
# Probability: 72
# Probability: 16
# Probability: 38
# Probability: 89
# Probability: 35
# Probability: 37
# Probability: 78
# Probability: 10
# Probability: 57
# Probability: 87
# Probability: 69
# Probability: 83
# Probability: 59
# Probability: 60
# Probability: 59
# Probability: 82
# Probability: 27
# Probability: 83
# Probability: 25
# Probability: 12
# Probability: 10
# Probability: 24
# Probability: 33
# Probability: 95
# Probability: 6
# Probability: 9
# Probability: 35
# Probability: 85
# Probability: 26
# Probability: 27
# Probability: 43
# Probability: 90
# Probability: 65
# Probability: 30
# Probability: 46
# Probability: 22
# Probability: 34
# Probability: 31
# Probability: 40
# Probability: 14
# Probability: 25
# Probability: 12
# Probability: 90
# Probability: 46
# Probability: 21
# Probability: 24
# Probability: 37
# Probability: 96
# Probability: 6
# Probability: 31
# Probability: 25
# Probability: 73
# Probability: 60
# Probability: 68
# Probability: 55
# Probability: 76
# Probability: 18
# Probability: 41
# Probability: 38
# Probability: 37
# Probability: 32
# Probability: 25
# Probability: 27
# Probability: 46
# Probability: 73
# Probability: 73
# Probability: 80
# Probability: 45
# Probability: 63
# Probability: 88
# Probability: 75
# Probability: 86
# Probability: 53
# Probability: 96
# Probability: 74
# Probability: 92
# Probability: 58
# Probability: 3
# Probability: 10
# Probability: 8
# Probability: 99
# Probability: 14
# Probability: 96
# Probability: 55
# Probability: 4
# Probability: 22
# Probability: 82
# Probability: 36
# Probability: 49
# Probability: 42
# Probability: 39
# Probability: 89
# Probability: 85
# Probability: 27
# Probability: 69
# Probability: 48
# Probability: 36
# Probability: 12
# Probability: 82
# Probability: 3
# Probability: 89
# Probability: 77
# Probability: 28
# Probability: 7
# Probability: 46
# Probability: 93
# Probability: 43
# Probability: 19
# Probability: 22
# Probability: 32
# Probability: 68
# Probability: 16
# Probability: 52
# Probability: 95
# Probability: 83
# Probability: 69
# Probability: 86
# Probability: 30
# Probability: 92
# Probability: 82
# Probability: 91
# Probability: 27
# Probability: 94
# Probability: 13
# Probability: 73
# Probability: 5
# Probability: 88
# Probability: 24
# Probability: 84
# Probability: 53
# Probability: 77
# Probability: 20
# Probability: 82
# Probability: 84
# Probability: 10
# Probability: 88
# Probability: 30
# Probability: 40
# Probability: 95
# Probability: 73
# Probability: 11
# Probability: 81
# Probability: 1
# Probability: 43
# Probability: 24
# Probability: 74
# Probability: 42
# Probability: 54
# Probability: 47
# Probability: 47
# Probability: 63
# Probability: 29
# Probability: 75
# Probability: 22
# Probability: 16
# Probability: 40
# Probability: 81
# Probability: 68
# Probability: 100
# Probability: 22
# Probability: 82
# Probability: 58
# Probability: 55
# Probability: 16
# Probability: 94
# Probability: 35
# Probability: 95
# Probability: 43
# Probability: 7
# Probability: 62
# Probability: 71
# Probability: 48
# Probability: 13
# Probability: 24
# Probability: 57
# Probability: 53
# Probability: 28
# Probability: 34
# Probability: 40
# Probability: 71
# Probability: 96
# Probability: 78
# Probability: 58
# Probability: 30
# Probability: 46
# Probability: 78
# Probability: 4
# Probability: 18
# Probability: 31
# Probability: 84
# Probability: 58
# Probability: 7
# Probability: 6
# Probability: 96
# Probability: 25
# Probability: 30
# Probability: 26
# Probability: 12
# Probability: 15
# Probability: 19
# Probability: 67
# Probability: 47
# Probability: 69
# Probability: 51
# Probability: 30
# Probability: 22
# Probability: 91
# Probability: 75
# Probability: 34
# Probability: 72
# Probability: 50
# Probability: 39
# Probability: 82
# Probability: 95
# Probability: 39
# Probability: 19
# Probability: 1
# Probability: 47
# Probability: 32
# Probability: 15
# Probability: 85
# Probability: 71
# Probability: 60
# Probability: 27
# Probability: 86
# Probability: 86
# Probability: 5
# Probability: 4
# Probability: 21
# Probability: 35
# Probability: 86
# Probability: 96
# Probability: 33
# Probability: 21
# Probability: 14
# Probability: 19
# Probability: 87
# Probability: 54
# Probability: 80
# Probability: 75
# Probability: 33
# Probability: 64
# Probability: 75
# Probability: 88
# Probability: 79
# Probability: 1
# Probability: 34
# Probability: 38
# Probability: 40
# Probability: 70
# Probability: 45
# Probability: 87
# Probability: 53
# Probability: 52
# Probability: 52
# Probability: 45
# Probability: 86
# Probability: 34
# Probability: 48
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/xf/sg7ngz3n4q78m3g2_www4h9w0000gq/T/ipykernel_97625/4114353283.py in <module>
#      69         if os.path.exists(annotation_path):
#      70             train_file.write(image_path + '\n')
# ---> 71             convert_annotation(nameWithoutExtention) # convert label
#      72             copyfile(image_path, yolov5_images_train_dir + voc_path)
#      73             copyfile(label_path, yolov5_labels_train_dir + label_name)
#
# /var/folders/xf/sg7ngz3n4q78m3g2_www4h9w0000gq/T/ipykernel_97625/3910397575.py in convert_annotation(image_id)
#      44     out_file.write(str(cls_id) + " " + " ".join([str(a) for a in bb]) + '\n')
#      45   in_file.close()
# ---> 46   out_file.close()
#
# KeyboardInterrupt:
